# %%
import pandas as pd
import numpy as np
import skimage as sk
import matplotlib.pyplot as plt


from skimage import io
# %matplotlib inline

# %%
img_file = input('Enter a filename: ')

# test path
# /Users/kpuhger/Box Sync/Personal/AAV_TRE images/prog report pics/114_728_GFP_only.tif
# Out:
# Enter a filename: /Users/kpuhger/Box Sync/Personal/AAV_TRE images/prog report pics/114_728_GFP_only.tif

# %%
f, ax = plt.subplots(1,1,figsize=(20,20))
img_raw = sk.io.imread(img_file)
ax.imshow(img_raw)
ax.set_axis_off();
